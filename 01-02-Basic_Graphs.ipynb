# %% [markdown]
# # Making road network of India's cities

# %%
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
G = nx.Graph() # Undirected Graph
G2 = nx.DiGraph() # Directed Graph

# %%
Cities = ['Delhi', 'Bangalore', 'Hyderabad', 'Ahmadabad', 'Channai', 'Kolkata', 'Pune', 'Jaipur']

# %%
for i in Cities:
    G.add_node(i)

# %%
nx.draw(G)

# %%
costs = []
value = 100

while value <= 2000:
    costs.append(value)
    value = value + 100

print(costs)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]

# %%
type(G.nodes())
# Out:
# networkx.classes.reportviews.NodeView

# %%
#we are going to add 16 edges in the graph G
while(G.number_of_edges() < 16):
    c1 = random.choice(list(G.nodes()))
    c2 = random.choice(list(G.nodes()))
    if(c1 != c2 and G.has_edge(c1,c2)==0):
        w = random.choice(costs)
        G.add_edge(c1,c2,weight=w)

# %%
nx.draw(G)
# Out:
# C:\Users\devel\.conda\envs\social_network\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
pos = nx.spectral_layout(G)
nx.draw(G, pos)

# %%
pos = nx.spring_layout(G)
nx.draw(G, pos)

# %%
pos = nx.circular_layout(G)
nx.draw(G, pos)

# %%
nx.draw_networkx_edge_labels(G, pos)
# Out:
# {('Delhi',
#   'Channai'): Text(1.8874474316810108e-08, -2.5332960139983302e-08, "{'weight': 1700}"),
#  ('Delhi',
#   'Jaipur'): Text(0.8535533575042462, -0.35355341909554727, "{'weight': 1300}"),
#  ('Delhi',
#   'Bangalore'): Text(0.8535533873065682, 0.3535533962477583, "{'weight': 1600}"),
#  ('Delhi',
#   'Hyderabad'): Text(0.4999999875815434, 0.5000000089411901, "{'weight': 900}"),
#  ('Delhi',
#   'Pune'): Text(0.5000000153996773, -0.4999999721843355, "{'weight': 500}"),
#  ('Bangalore',
#   'Channai'): Text(-0.14644659381895758, 0.3535533525363708, "{'weight': 1000}"),
#  ('Bangalore',
#   'Kolkata'): Text(-1.0927847515773692e-08, 4.81807491681252e-08, "{'weight': 600}"),
#  ('Hyderabad',
#   'Ahmadabad'): Text(-0.3535533808505504, 0.8535533868105212, "{'weight': 500}"),
#  ('Hyderabad',
#   'Jaipur'): Text(0.35355334508578967, 0.14644657146721557, "{'weight': 2000}"),
#  ('Hyderabad',
#   'Pune'): Text(2.9812207694906008e-09, 1.8378427335541403e-08, "{'weight': 1300}"),
#  ('Ahmadabad',
#   'Channai'): Text(-0.8535533495576195, 0.3535533525363708, "{'weight': 1600}"),
#  ('Ahmadabad',
#   'Jaipur'): Text(-1.0927847515773692e-08, -4.12262163296262e-08, "{'weight': 1100}"),
#  ('Channai',
#   'Jaipur'): Text(-0.14644662362127941, -0.3535534628069347, "{'weight': 1000}"),
#  ('Channai',
#   'Pune'): Text(-0.4999999657258483, -0.500000015895723, "{'weight': 900}"),
#  ('Kolkata',
#   'Jaipur'): Text(-4.073016934835749e-08, -0.7071067671625564, "{'weight': 1300}"),
#  ('Kolkata',
#   'Pune'): Text(-0.35355338283473825, -0.8535533202513446, "{'weight': 1800}")}

# %%
nx.is_connected(G)
# Out:
# True

# %%
edges = list(G.edges())
G.remove_edges_from(edges)
#we are going to add 16 edges in the graph G
while(G.number_of_edges() < 10):
    c1 = random.choice(list(G.nodes()))
    c2 = random.choice(list(G.nodes()))
    if(c1 != c2 and G.has_edge(c1,c2)==0):
        w = random.choice(costs)
        G.add_edge(c1,c2,weight=w)
pos = nx.circular_layout(G)
nx.draw(G, pos)
print(nx.is_connected(G))
# Out:
# True

# %%
for u in G.nodes():
    for v in G.nodes():
        print (u, v, nx.has_path(G, u, v))
# Out:
# Delhi Delhi True
# Delhi Bangalore True
# Delhi Hyderabad True
# Delhi Ahmadabad False
# Delhi Channai False
# Delhi Kolkata True
# Delhi Pune True
# Delhi Jaipur True
# Bangalore Delhi True
# Bangalore Bangalore True
# Bangalore Hyderabad True
# Bangalore Ahmadabad False
# Bangalore Channai False
# Bangalore Kolkata True
# Bangalore Pune True
# Bangalore Jaipur True
# Hyderabad Delhi True
# Hyderabad Bangalore True
# Hyderabad Hyderabad True
# Hyderabad Ahmadabad False
# Hyderabad Channai False
# Hyderabad Kolkata True
# Hyderabad Pune True
# Hyderabad Jaipur True
# Ahmadabad Delhi False
# Ahmadabad Bangalore False
# Ahmadabad Hyderabad False
# Ahmadabad Ahmadabad True
# Ahmadabad Channai False
# Ahmadabad Kolkata False
# Ahmadabad Pune False
# Ahmadabad Jaipur False
# Channai Delhi False
# Channai Bangalore False
# Channai Hyderabad False
# Channai Ahmadabad False
# Channai Channai True
# Channai Kolkata False
# Channai Pune False
# Channai Jaipur False
# Kolkata Delhi True
# Kolkata Bangalore True
# Kolkata Hyderabad True
# Kolkata Ahmadabad False
# Kolkata Channai False
# Kolkata Kolkata True
# Kolkata Pune True
# Kolkata Jaipur True
# Pune Delhi True
# Pune Bangalore True
# Pune Hyderabad True
# Pune Ahmadabad False
# Pune Channai False
# Pune Kolkata True
# Pune Pune True
# Pune Jaipur True
# Jaipur Delhi True
# Jaipur Bangalore True
# Jaipur Hyderabad True
# Jaipur Ahmadabad False
# Jaipur Channai False
# Jaipur Kolkata True
# Jaipur Pune True
# Jaipur Jaipur True

# %%
edges = list(G.edges())
G.remove_edges_from(edges)
#we are going to add 16 edges in the graph G
while(G.number_of_edges() < 5):
    c1 = random.choice(list(G.nodes()))
    c2 = random.choice(list(G.nodes()))
    if(c1 != c2 and G.has_edge(c1,c2)==0):
        w = random.choice(costs)
        G.add_edge(c1,c2,weight=w)
pos = nx.circular_layout(G)
nx.draw(G, pos)
print(nx.is_connected(G))
# Out:
# False
